# %% [markdown]
# # Homework

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Make a tuple containing natural numbers, the square of which is a multiple of 3, 4, but not a multiple of 8 and not exceeding 12345.

# %%
tup = tuple((filter(lambda x: (x*x) % 6 == 0 and (x*x) % 8 != 0, range(1, 12345))))
print(tup)
# Out:
# (6, 18, 30, 42, 54, 66, 78, 90, 102, 114, 126, 138, 150, 162, 174, 186, 198, 210, 222, 234, 246, 258, 270, 282, 294, 306, 318, 330, 342, 354, 366, 378, 390, 402, 414, 426, 438, 450, 462, 474, 486, 498, 510, 522, 534, 546, 558, 570, 582, 594, 606, 618, 630, 642, 654, 666, 678, 690, 702, 714, 726, 738, 750, 762, 774, 786, 798, 810, 822, 834, 846, 858, 870, 882, 894, 906, 918, 930, 942, 954, 966, 978, 990, 1002, 1014, 1026, 1038, 1050, 1062, 1074, 1086, 1098, 1110, 1122, 1134, 1146, 1158, 1170, 1182, 1194, 1206, 1218, 1230, 1242, 1254, 1266, 1278, 1290, 1302, 1314, 1326, 1338, 1350, 1362, 1374, 1386, 1398, 1410, 1422, 1434, 1446, 1458, 1470, 1482, 1494, 1506, 1518, 1530, 1542, 1554, 1566, 1578, 1590, 1602, 1614, 1626, 1638, 1650, 1662, 1674, 1686, 1698, 1710, 1722, 1734, 1746, 1758, 1770, 1782, 1794, 1806, 1818, 1830, 1842, 1854, 1866, 1878, 1890, 1902, 1914, 1926, 1938, 1950, 1962, 1974, 1986, 1998, 2010, 2022, 2034, 2046, 2058, 2070, 2082, 2094, 2106, 2118, 2130, 2142, 2154, 2166, 217
# ...

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Write a function that takes a two-dimensional array and a string as input and returns an array rotated 90 degrees counterclockwise if the string 'left' was passed, and clockwise if the string 'right' was passed.
#
# Example for input: $\begin{bmatrix} 1 & 2 & 3 \\ 4 & 5 & 6 \\ 7 & 8 & 9 \end{bmatrix}$.\
# If the string 'left' is passed, the function should return $\begin{bmatrix} 3 & 6 & 9 \\ 2 & 5 & 8 \\ 1 & 4 & 7 \end{bmatrix}$, and if the string 'right' is passed, the function should return $\begin{bmatrix} 7 & 4 & 1 \\ 8 & 5 & 2 \\ 9 & 6 & 3 \end{bmatrix}$.
#
# Do not use numpy and nested loops. Use list comprehensions and built-in function `zip`.

# %%
m = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
    ]


def rotatetetteet(m, turn):
  if turn == 'left':
    return tuple(zip(*m))[::-1]
  elif turn == "right":
    return tuple(zip(*(m[::-1])))

print(rotatetetteet(m, "right"))
# Out:
# ((7, 4, 1), (8, 5, 2), (9, 6, 3))

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Write a function that takes a string as input and returns a dictionary containing the number of occurrences of each character in the string. Use method `count` of strings. Implement this function in one line using $\lambda$-function.
#
# Example for the string 'hello, world!': {'h': 1, 'e': 1, 'l': 3, 'o': 2, ',': 1, ' ': 1, 'w': 1, 'r': 1, 'd': 1, '!': 1}.

# %%
#fah = str(input())
#d = {}
#for x in fah:
   #d[x] = fah.count(x)
#print(d)


meow = lambda x: {s: x.count(s) for s in x}
gav = str(input())
print(meow(gav))
# Out:
# I love RDR2!
# {'I': 1, ' ': 2, 'l': 1, 'o': 1, 'v': 1, 'e': 1, 'R': 2, 'D': 1, '2': 1, '!': 1}

# %% [markdown]
# ## Problem 4

# %% [markdown]
# ### Implementing a Library Management System
#
# #### Description
#
# You are required to design and implement a system for managing books and users in a library. The system should allow for the management of books (adding, deleting, searching by various criteria) and users (registration, deletion, searching), as well as tracking the history of interactions between them (issuing and returning books).
#
# #### Tasks
#
# 1. **`Book` Class**:
#    - Attributes: title, author, year of publication, ISBN, number of copies.
#    - Methods: constructor, methods to get information about the book, method to change the number of copies (when issuing and returning books).
#
# 2. **`User` Class**:
#    - Attributes: user name, library card number, list of borrowed books.
#    - Methods: constructor, methods for user registration, methods for adding and removing books from the borrowed list.
#
# 3. **`Library` Class**:
#    - Attributes: list of books, list of users, transaction history (who, when, which book was borrowed and returned).
#    - Methods: constructor, methods for adding and deleting books and users, methods for issuing and returning books, searching for books and users by various criteria, method to display the transaction history.
#
# #### Assignment
#
# 1. Implement the `Book`, `User`, and `Library` classes with the specified attributes and methods.
# 2. Create several books and users, and add them to the library system.
# 3. Implement scenarios for issuing books to users and their return.
# 4. Display the transaction history to show how books were issued and returned.

# %%
class Book:

  def __init__(self, title, author, year, ISBN, copies):
    self.title = title
    self.author = author
    self.year = year
    self.ISBN = ISBN
    self.copies = copies
    print(f"Book {title} added")

  def get_info(self):
    return f"Info about {self.title}: Author: {self.author}, Year of publication: {self.year}, ISBN: {self.ISBN}, Number of copies: {self.copies}"

  def take_book(self):
    if self.copies > 0:
      self.copies -= 1
      return True
    return False
  def bring_book(self):
    self.copies += 1
    return True



class User:


  def __init__(self, name, card_number):
    self.name = name
    self.card_number = card_number
    self.books = []
    print(f"User {self.name} registered")

  def borrow(self, book):
    if book.take_book():
      self.books.append(book)
      return True
    return False

  def return_book(self, book):
    if book in self.books:
      book.bring_book()
      self.books.remove(book)
      return True
    return False



class Library:

  def __init__(self):
    self.books = []
    self.users = []
    self.transaction_history = []
    print("Library system created")

  def add_book(self, book):
    self.books.append(book)

  def remove_book(self, book):
      if book in self.books:
          self.books.remove(book)
          print(f"Book {book.title} removed")
      else:
        print("Error")

  def register_user(self, user):
    self.users.append(user)

  def deregister_user(self, user):
    if user in self.users:
      self.users.remove(user)
      print(f"User {user.name} deregistered")
    else:
      print("Error")

  def issue_book(self, user, book):
        if user in self.users and book in self.books:
            if user.borrow(book):
                self.transaction_history.append(f"{user.name} took {book.title}")
                #print(такой пользователь взял книгу. хз надо это отдельно добавлять?)
                return True
        return False

  def return_book(self, user, book):
    if user.return_book(book):
      self.transaction_history.append(f"{user.name} returned {book.title}")
      return True
    return False


  def find_book_title(self, title):

    for book in self.books:
      meow = book.get_info()
      if book.title == title:
        print(f"Found {meow}")
    return None

  def find_book_author(self, author):
    for book in self.books:
      if book.author == author:
        return book
    return None

  def find_user_card(self, card_number):
    for user in self.users:
        if user.card_number == card_number:
            return user
    return None

  def find_user_name(self, name):
    for user in self.users:
        if user.name == name:
            return user
    return None



  def display_transaction_history(self):
    for x in self.transaction_history:
      print(x)



system = Library()

book1 = Book("Black obelisk", "Erich Maria Remarque", 1956, 6767, 10 )
book2 = Book("1984", "George Orwell", 1949, 6768, 5)
system.add_book(book1)
system.add_book(book2)


user1 = User("Vaclovas", 2026)
user2 = User("Danya", 123)
system.register_user(user1)
system.register_user(user2)
system.deregister_user(user2)

system.issue_book(user1, book1)
system.issue_book(user1, book2)
system.return_book(user1, book1)
system.issue_book(user2, book1)

system.display_transaction_history()

system.find_book_title("1984")
# Out:
# Library system created
# Book Black obelisk added
# Book 1984 added
# User Vaclovas registered
# User Danya registered
# User Danya deregistered
# Vaclovas took Black obelisk
# Vaclovas took 1984
# Vaclovas returned Black obelisk
# Found Info about 1984: Author: George Orwell, Year of publication: 1949, ISBN: 6768, Number of copies: 4

# %% [markdown]
# ## Problem 5*

# %% [markdown]
# Explain why list `b` changes after the execution of the following code:
#
# ```python
# a = [1, 2, 3]
# b = a
# a[0] = 4
# print(b)
# ```

# %%
a = [1, 2, 3]
b = a
print(b)
a[0] = 4
print(a)
print(b)


#ну b это просто ссылка на a и поэтому переходя по b мы попадем в измененный а
#ну b это просто ссылка на a и поэтому переходя по b мы попадем в измененный а
#ну b это просто ссылка на a и поэтому переходя по b мы попадем в измененный а
#ну b это просто ссылка на a и поэтому переходя по b мы попадем в измененный а
# Out:
# [1, 2, 3]
# [4, 2, 3]
# [4, 2, 3]

# %% [markdown]
# > Write your answer in markdown cell after:

# %% [markdown]
# ## Problem 6*

# %% [markdown]
# Let
# $$A = \sum_{i=1}^{10000} \frac{1}{i^2},\quad B=\sum_{i=10000}^{1} \frac{1}{i^2}.$$
# Calculate the values of $A$ and $B$ and compare them. What do you observe? Explain why this happens. What is the best way to calculate the value of $\sum\limits_{i=1}^{10000} \dfrac{1}{i^2}$?

# %%
a = 0
b = 0
for i in range(1, 10001):
  a += 1/(i**2)
for i in range(1, 10001):
  b += 1/((10001-i)**2)
print(a)
print(b)


# из-за округления флоат каждое суммирование берет близкое округленное число
# поэтому будет важен порядок тк при суммировании большой суммы с малым числом
# маленький вклад может потеряться(большое число задает порядок),
# поэтому при складывании в прямом порядке больше ошибка и лучше складывать в обратном
# Out:
# 1.6448340718480652
# 1.6448340718480596
